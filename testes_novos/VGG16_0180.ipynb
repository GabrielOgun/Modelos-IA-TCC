# %% [markdown]
# #DATASET FULL COM DA
# ###PRIMEIRO DIGITO DATASET 0 = FULL 1 = BALANCEADO
# ###SEGUNDO DIGITO DA 0 = NAO 1 = SIM
# ###ultimos dois numero de epocas = 80
# ###tamanho padrao do modelo 224
# ###lote 64
# ###tambem aumentei validation para 0.2

# %%
#importando drive com imagens
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pathlib


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D # Updated import statements
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import regularizers
from keras import metrics

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.17.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, requests, setuptools, six, tensorboard, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by: dopamine_rl, tf_keras

# %%
train_dir = pathlib.Path("/content/drive/MyDrive/DATASET/Dataset_full/ds_train")
test_dir = pathlib.Path("/content/drive/MyDrive/DATASET/Dataset_full/ds_test")
print(train_dir)
print(test_dir)
# Out:
# /content/drive/MyDrive/DATASET/Dataset_full/ds_train
# /content/drive/MyDrive/DATASET/Dataset_full/ds_test

# %%
#tamanho de imagem
vgg16_img_size = 224
#número de exemplos que serão processados juntos em uma única iteração do modelo durante o treinamento
vgg16_batch_size = 64

# Dataset de treino
vgg16_train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,  # Dividir 20% dos dados para validação
    subset="training",     # Definir que esta é a parte de treino
    seed=123,
    image_size=(vgg16_img_size, vgg16_img_size),
    batch_size=vgg16_batch_size)

# Dataset de validação
vgg16_val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,  # Usar 20% dos dados para validação
    subset="validation",   # Definir que esta é a parte de validação
    seed=123,
    image_size=(vgg16_img_size, vgg16_img_size),
    batch_size=vgg16_batch_size)

# Dataset de teste
vgg16_test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    seed=123,
    image_size=(vgg16_img_size, vgg16_img_size),
    batch_size=vgg16_batch_size)


classes_train = vgg16_train_ds.class_names
classes_val = vgg16_val_ds.class_names
class_names = vgg16_test_ds.class_names

print(f"Classes de teste: {class_names}, classes de validação: {classes_val}, classes de treino: {classes_train}")
# Out:
# Found 43028 files belonging to 5 classes.
# Using 34423 files for training.
# Found 43028 files belonging to 5 classes.
# Using 8605 files for validation.
# Found 4779 files belonging to 5 classes.
# Classes de teste: ['basal_cell_carcinoma', 'melanoma', 'nevus', 'seborrheic_keratosis', 'squamous_cell_carcinoma'], classes de validação: ['basal_cell_carcinoma', 'melanoma', 'nevus', 'seborrheic_keratosis', 'squamous_cell_carcinoma'], classes de treino: ['basal_cell_carcinoma', 'melanoma', 'nevus', 'seborrheic_keratosis', 'squamous_cell_carcinoma']

# %%
for image_batch, labels_batch in vgg16_train_ds:
  vgg16_train_img = image_batch
  vgg16_train_labels = labels_batch
  break
for image_batch, labels_batch in vgg16_val_ds:
  vgg16_val_img = image_batch
  vgg16_val_labels = labels_batch
  break
for image_batch, labels_batch in vgg16_test_ds:
  vgg16_test_img = image_batch
  vgg16_test_labels = labels_batch
  break

# %%
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(vgg16_train_img[i].numpy().astype("uint8"))
    plt.title(int(vgg16_train_labels[i]))
    plt.axis("off")

# %%
# ajusta automaticamente o número de threads para o pré-processamento dos dados. melhorar a performance e a eficiência do pipeline de dados.
AUTOTUNE = tf.data.experimental.AUTOTUNE

vgg16_train_ds = vgg16_train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
vgg16_val_ds = vgg16_val_ds.cache().prefetch(buffer_size=AUTOTUNE)
vgg16_test_ds = vgg16_test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#aumentando a diversidade do conjunto de treinamento
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
  ]
)

# %%
# VGG16
img_shape = (vgg16_img_size,vgg16_img_size,3)
VGG16_model = tf.keras.applications.VGG16(input_shape=img_shape,include_top=False,weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
VGG16_model.trainable=False
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
prediction_layer = tf.keras.layers.Dense(5,activation='relu',bias_regularizer=regularizers.l2(1e-4))

# %%
from tensorflow.keras import layers, models, regularizers

num_classes = 5

vgg16_model = models.Sequential([
    data_augmentation,                   # Camada de aumento de dados
    VGG16_model,                         # Modelo base VGG16 congelado
    global_average_layer,                # Global Average Pooling para achatar a saída
    layers.BatchNormalization(),         # Normalização por batch após GlobalAveragePooling
    layers.Dense(256, activation='relu', # Camada densa intermediária com 256 neurônios
                 bias_regularizer=regularizers.l2(1e-4)),
    layers.Dropout(0.5),                 # Dropout para evitar overfitting
    layers.Dense(num_classes, activation='softmax')  # Camada final para 5 classes
])

# %%
vgg16_model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
epochs = 80
history = vgg16_model.fit(
  vgg16_train_ds,
  validation_data=vgg16_val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/80
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/nn.py:609: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 3353s 1s/step - accuracy: 0.6702 - loss: 0.9872 - val_accuracy: 0.7421 - val_loss: 0.7336
# Epoch 2/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7303 - loss: 0.7113 - val_accuracy: 0.7455 - val_loss: 0.6918
# Epoch 3/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7491 - loss: 0.6775 - val_accuracy: 0.7422 - val_loss: 0.6954
# Epoch 4/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 182ms/step - accuracy: 0.7545 - loss: 0.6550 - val_accuracy: 0.7576 - val_loss: 0.6512
# Epoch 5/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 182ms/step - accuracy: 0.7522 - loss: 0.6533 - val_accuracy: 0.7537 - val_loss: 0.6447
# Epoch 6/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7519 - loss: 0.6510 - val_accuracy: 0.7515 - val_loss: 0.6597
# Epoch 7/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7582 - loss: 0.6409 - val_accuracy: 0.7576 - val_loss: 0.6440
# Epoch 8/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 182ms/step - accuracy: 0.7640 - loss: 0.6317 - val_accuracy: 0.7590 - val_loss: 0.6326
# Epoch 9/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7634 - loss: 0.6320 - val_accuracy: 0.7633 - val_loss: 0.6293
# Epoch 10/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7628 - loss: 0.6213 - val_accuracy: 0.7577 - val_loss: 0.6398
# Epoch 11/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 182ms/step - accuracy: 0.7676 - loss: 0.6145 - val_accuracy: 0.7634 - val_loss: 0.6255
# Epoch 12/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7660 - loss: 0.6176 - val_accuracy: 0.7583 - val_loss: 0.6425
# Epoch 13/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7726 - loss: 0.6076 - val_accuracy: 0.7577 - val_loss: 0.6583
# Epoch 14/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7644 - loss: 0.6153 - val_accuracy: 0.7636 - val_loss: 0.6337
# Epoch 15/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7688 - loss: 0.6095 - val_accuracy: 0.7629 - val_loss: 0.6351
# Epoch 16/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7720 - loss: 0.6039 - val_accuracy: 0.7601 - val_loss: 0.6305
# Epoch 17/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7733 - loss: 0.5963 - val_accuracy: 0.7621 - val_loss: 0.6243
# Epoch 18/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7700 - loss: 0.6047 - val_accuracy: 0.7627 - val_loss: 0.6261
# Epoch 19/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7703 - loss: 0.6039 - val_accuracy: 0.7651 - val_loss: 0.6253
# Epoch 20/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7739 - loss: 0.5880 - val_accuracy: 0.7637 - val_loss: 0.6274
# Epoch 21/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7718 - loss: 0.5979 - val_accuracy: 0.7673 - val_loss: 0.6199
# Epoch 22/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7785 - loss: 0.5848 - val_accuracy: 0.7632 - val_loss: 0.6280
# Epoch 23/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7755 - loss: 0.5913 - val_accuracy: 0.7620 - val_loss: 0.6295
# Epoch 24/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7780 - loss: 0.5847 - val_accuracy: 0.7610 - val_loss: 0.6377
# Epoch 25/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7777 - loss: 0.5844 - val_accuracy: 0.7668 - val_loss: 0.6300
# Epoch 26/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.
80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7891 - loss: 0.5491 - val_accuracy: 0.7713 - val_loss: 0.6332
# Epoch 60/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7939 - loss: 0.5462 - val_accuracy: 0.7732 - val_loss: 0.6154
# Epoch 61/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7914 - loss: 0.5449 - val_accuracy: 0.7772 - val_loss: 0.6144
# Epoch 62/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7919 - loss: 0.5388 - val_accuracy: 0.7741 - val_loss: 0.6169
# Epoch 63/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7906 - loss: 0.5403 - val_accuracy: 0.7669 - val_loss: 0.6271
# Epoch 64/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7964 - loss: 0.5299 - val_accuracy: 0.7701 - val_loss: 0.6294
# Epoch 65/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7964 - loss: 0.5346 - val_accuracy: 0.7713 - val_loss: 0.6232
# Epoch 66/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7904 - loss: 0.5477 - val_accuracy: 0.7763 - val_loss: 0.6169
# Epoch 67/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7904 - loss: 0.5484 - val_accuracy: 0.7704 - val_loss: 0.6349
# Epoch 68/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7933 - loss: 0.5411 - val_accuracy: 0.7709 - val_loss: 0.6457
# Epoch 69/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7905 - loss: 0.5420 - val_accuracy: 0.7725 - val_loss: 0.6202
# Epoch 70/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7945 - loss: 0.5388 - val_accuracy: 0.7714 - val_loss: 0.6213
# Epoch 71/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7891 - loss: 0.5475 - val_accuracy: 0.7719 - val_loss: 0.6385
# Epoch 72/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7931 - loss: 0.5388 - val_accuracy: 0.7716 - val_loss: 0.6239
# Epoch 73/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7949 - loss: 0.5395 - val_accuracy: 0.7764 - val_loss: 0.6283
# Epoch 74/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7924 - loss: 0.5431 - val_accuracy: 0.7658 - val_loss: 0.6465
# Epoch 75/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7892 - loss: 0.5422 - val_accuracy: 0.7749 - val_loss: 0.6157
# Epoch 76/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7870 - loss: 0.5439 - val_accuracy: 0.7761 - val_loss: 0.6269
# Epoch 77/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7918 - loss: 0.5419 - val_accuracy: 0.7686 - val_loss: 0.6327
# Epoch 78/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7940 - loss: 0.5359 - val_accuracy: 0.7673 - val_loss: 0.6200
# Epoch 79/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7987 - loss: 0.5283 - val_accuracy: 0.7721 - val_loss: 0.6242
# Epoch 80/80
# 538/538 ━━━━━━━━━━━━━━━━━━━━ 98s 183ms/step - accuracy: 0.7983 - loss: 0.5286 - val_accuracy: 0.7757 - val_loss: 0.6173

# %%
vgg16_loss, vgg16_acc = vgg16_model.evaluate(vgg16_test_ds)
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 348s 5s/step - accuracy: 0.7171 - loss: 0.7484

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

y_pred = []  # Lista para armazenar previsões
y_true = []  # Lista para armazenar os rótulos verdadeiros

# Passar por todos os batches do conjunto de teste
for images, labels in vgg16_test_ds:
    # Gerar previsões
    preds = vgg16_model.predict(images)
    # Armazenar as previsões
    y_pred.extend(np.argmax(preds, axis=1))  # Armazenar o índice da classe predita
    y_true.extend(labels.numpy())  # Armazenar diretamente os índices das classes verdadeiras

# Converter para arrays numpy
y_pred = np.array(y_pred)
y_true = np.array(y_true)

# 3. Gerar a matriz de confusão
conf_matrix = confusion_matrix(y_true, y_pred)

# 4. Imprimir o classification report
print("\nRelatório de Classificação:\n")
print(classification_report(y_true, y_pred, target_names=class_names))

# 5. Visualizar a matriz de confusão
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Classe Predita')
plt.ylabel('Classe Verdadeira')
plt.title('Matriz de Confusão')
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Relatório de Classificação:
#
#                          precision    recall  f1-score   support
#
#    basal_cell_carcinoma       0.66      0.13      0.21       477
#                melanoma       0.68      0.25      0.36       722
#                   nevus       0.73      0.99      0.84      3260
#    seborrheic_keratosis       0.20      0.03      0.05       190
# squamous_cell_carcinoma       0.25      0.02      0.03       130
#
#                accuracy                           0.72      4779
#               macro avg       0.50      0.28      0.30      4779
#            weighted avg       0.68      0.72      0.65      4779
